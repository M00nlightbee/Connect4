# %% [markdown]
# # <font color= "magenta">  ****Smart (Rule-based) agent vs Mini-max agent****</font>

# %% [markdown]
# **1. Import required libraries**

# %%
import time
import random
import numpy as np
from Connect4 import Connect4
from RuleBasedAgent import RuleBasedAgent
from MiniMax import MiniMax

# %% [markdown]
# **2. Play game**

# %%
def play_game(verbose=False):
    game = Connect4()
    minimax_agent = MiniMax(game)
    rule_based = RuleBasedAgent(game)

    while True:
        if verbose:
            game.display_board()
            available_cols = game.get_available_moves(game.board)
            print(f"Available columns: {available_cols}")

        if game.current_player == "●":
            col = minimax_agent.best_move()
            if verbose:
                print("MiniMax AI's turn")
                print(f"MiniMax AI chooses column: {col}")
        else:
            col = rule_based.rule_based_agent(game.board)
            if verbose:
                print("Rule Based AI's turn")
                print(f"Rule Based AI chooses column: {col}")

        if col is None:
            return "draw"

        game.make_move(col, game.current_player)

        if game.check_winner("○"):
            return "rule_based"
        elif game.check_winner("●"):
            return "minimax"
        elif game.is_full(game.board):
            return "draw"

        game.current_player = "○" if game.current_player == "●" else "●"

# %% [markdown]
# **3. Run Game funcion**

# %%
if __name__ == "__main__":
    start_time = time.time()
    minimax_wins = 0
    rule_based_wins = 0
    draws = 0
    total_games = 100

    for i in range(total_games):
        game_result = play_game()
        if game_result == "minimax":
            minimax_wins += 1
        elif game_result == "rule_based":
            rule_based_wins += 1
        else:
            draws += 1

    end_time = time.time()
    duration = end_time - start_time

    print("----Smart (Rule-based) agent vs mini-max agent----")
    print(f"\nResults after {total_games} games:")
    print(f"MiniMax Agent wins: {minimax_wins}")
    print(f"Rule-Based Agent wins: {rule_based_wins}")
    print(f"Draws: {draws}")
    print(f"Total time taken: {duration:.2f} seconds")
# Out:
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 6, Score: 4
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: -3
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: -6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: -22
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -17
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: -19
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 1
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: -4
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -9
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: -22
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: -31
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: -29
# Available moves for AI: [0, 1, 2, 4, 5, 6]
# Best move selected: 4, Score: -35
# Available moves for AI: [0, 1, 2, 5, 6]
# Best move selected: 6, Score: -37
# Available moves for AI: [0, 1, 2, 5, 6]
# Best move selected: 1, Score: -34
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 6, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 3
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 5
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 6, Score: 4
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 2
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: -5
# Available moves for AI: [0, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -7
# Available moves for AI: [0, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: -7
# Available moves for AI: [0, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: -9
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 3
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -5
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: -2
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 3
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 6, Score: -11
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: -11
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: -14
# Available moves for AI: [1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -22
# Available moves for AI: [1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: -21
# Available moves for AI: [1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: -10
# Available moves for AI: [1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -9
# Available moves for AI: [1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -11
# Available moves for AI: [1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -24
# Available moves for AI: [1, 3, 4, 5, 6]
# Best move selected: 5, Score: -23
# Available moves for AI: [1, 4, 5, 6]
# Best move selected: 1, Score: -28
# Available moves for AI: [4, 5, 6]
# Best move selected: 4, Score: -14
# Available moves for AI: [4, 5, 6]
# Best move selected: 4, Score: -11
# Available moves for AI: [4, 5, 6]
# Best move selected: 4, Score: 4
# Available moves for AI: [5, 6]
# Best move selected: 5, Score: 0
# Available moves for AI: [5, 6]
# Best move selected: 5, Score: -7
# Available moves for AI: [6]
# Best move selected: 6, Score: -9
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 4
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 3
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 3
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: -1
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -10
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 1
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: -3
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: -5
# Available moves for AI: [0, 1, 2, 3, 5, 6]
# Best move selected: 2, Score: -7
# Available moves for AI: [0, 1, 2, 3, 5, 6]
# Best move selected: 2, Score: -9
# Available moves for AI: [0, 1, 3, 5, 6]
# Best move selected: 3, Score: -7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 11
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 6, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 2
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 4
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 3
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: -5
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 6, Score: 2
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 6, Score: -2
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: -5
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: -7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 3
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: -7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 10
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 10
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 1
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 5
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: -3
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: -5
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 6, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 4
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: -4
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: -7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: -5
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: -14
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: -19
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: -19
# Available moves for AI: [0, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -29
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: -5
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: -9
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: -11
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 6, Score: -7
# Available moves for AI: [1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -16
# Available moves for AI: [1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -17
# Available moves for AI: [1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: -9
# Available moves for AI: [1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: -9
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: -7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 5
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: -5
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 2
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 2
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: -1
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: -8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -11
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: -11
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: -25
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: -27
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 6, Score: -9
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -30
# Available moves for AI: [0, 1, 3, 4, 5, 6]
# Best move selected: 5, Score: -31
# Available moves for AI: [0, 3, 4, 5, 6]
# Best move selected: 3, Score: -41
# Available moves for AI: [0, 5, 6]
# Best move selected: 5, Score: -5
# Available moves for AI: [0, 6]
# Best move selected: 6, Score: -7
# Available moves for AI: [0, 6]
# Best move selected: 0, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 1
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 6, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: -5
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: -7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 2
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 6, Score: -2
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 4
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -3
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: -5
# Available moves for AI: [1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: -5
# Available moves for AI: [2, 3, 4, 5, 6]
# Best move selected: 5, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 3
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 6, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 10
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: -7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: -8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 5
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: -8
# Available moves for AI: [0, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 10
# Available moves for AI: [0, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 10
# Available moves for AI: [0, 3, 4, 5, 6]
# Best move selected: 3, Score: 8
# Available moves for AI: [0, 4, 5, 6]
# Best move selected: 4, Score: 10
# Available moves for AI: [0, 5, 6]
# Best move selected: 0, Score: -5
# Available moves for AI: [0, 5, 6]
# Best move selected: 6, Score: 10
# Available moves for AI: [0, 5]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: -1
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: -5
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: -7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 8
# Available moves for AI: [0, 1, 2, 4, 5, 6]
# Best move selected: 1, Score: -7
# Available moves for AI: [0, 1, 2, 4, 5, 6]
# Best move selected: 2, Score: 10
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: -5
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: -2
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: -11
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: -14
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: -13
# Available moves for AI: [0, 1, 2, 3, 4, 6]
# Best move selected: 4, Score: -27
# Available moves for AI: [0, 1, 2, 3, 4, 6]
# Best move selected: 6, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 6]
# Best move selected: 4, Score: -9
# Available moves for AI: [0, 1, 2, 3, 4, 6]
# Best move selected: 2, Score: -3
# Available moves for AI: [0, 1, 2, 3, 4, 6]
# Best move selected: 2, Score: 8
# Available moves for AI: [0, 1, 3, 4, 6]
# Best move selected: 0, Score: -24
# Available moves for AI: [0, 1, 3, 4, 6]
# Best move selected: 3, Score: 10
# Available moves for AI: [0, 1, 6]
# Best move selected: 0, Score: -18
# Available moves for AI: [0, 1, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [1, 6]
# Best move selected: 1, Score: 0
# Available moves for AI: [6]
# Best move selected: 6, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 4
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 4
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 2
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 6, Score: 2
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: -8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: -10
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 3
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 3
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: -7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: -7
# Available moves for AI: [0, 1, 2, 3, 4, 5]
# Best move selected: 4, Score: -17
# Available moves for AI: [0, 1, 2, 3]
# Best move selected: 2, Score: -16
# Available moves for AI: [0, 1, 2, 3]
# Best move selected: 2, Score: 8
# Available moves for AI: [0, 1, 2, 3]
# Best move selected: 3, Score: 10
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 6, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 3
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: -6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: -10
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: -10
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: -5
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: -5
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: -5
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: -5
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 6, Score: 10
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 10
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -5
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: -9
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 10
# Available moves for AI: [1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -12
# Available moves for AI: [1, 2, 3, 4, 5, 6]
# Best move selected: 6, Score: -20
# Available moves for AI: [2, 3, 4, 5, 6]
# Best move selected: 2, Score: -4
# Available moves for AI: [3, 4, 5, 6]
# Best move selected: 3, Score: 6
# Available moves for AI: [4, 6]
# Best move selected: 4, Score: 8
# Available moves for AI: [6]
# Best move selected: 6, Score: 10
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 2
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 6, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 5
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -12
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: -7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: -17
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: -25
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -15
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: -32
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: -36
# Available moves for AI: [0, 1, 3, 4, 5, 6]
# Best move selected: 1, Score: -33
# Available moves for AI: [0, 3, 4, 5, 6]
# Best move selected: 4, Score: -25
# Available moves for AI: [0, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [4, 5, 6]
# Best move selected: 4, Score: 0
# Available moves for AI: [6]
# Best move selected: 6, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 5
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: -5
# Available moves for AI: [0, 1, 2, 4, 5, 6]
# Best move selected: 5, Score: 4
# Available moves for AI: [0, 1, 2, 5, 6]
# Best move selected: 5, Score: 8
# Available moves for AI: [0, 1, 2, 5, 6]
# Best move selected: 2, Score: 1
# Available moves for AI: [0, 1, 2, 5, 6]
# Best move selected: 1, Score: 6
# Available moves for AI: [0, 1, 2, 5, 6]
# Best move selected: 2, Score: 6
# Available moves for AI: [0, 1, 2, 5, 6]
# Best move selected: 5, Score: 10
# Available moves for AI: [0, 1, 2, 6]
# Best move selected: 0, Score: -5
# Available moves for AI: [0, 2, 6]
# Best move selected: 0, Score: -5
# Available moves for AI: [0, 2, 6]
# Best move selected: 0, Score: -5
# Available moves for AI: [0, 2, 6]
# Best move selected: 2, Score: 10
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 2
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: -5
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 6, Score: 2
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 2
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: -7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: -7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: -7
# Available moves for AI: [0, 1, 2, 3, 5, 6]
# Best move selected: 6, Score: -5
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 4
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: -8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 6, Score: -7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -5
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: -7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: -6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 4
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 2
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 6, Score: 3
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 6, Score: -1
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 3
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 10
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 10
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -17
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: -20
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 10
# Available moves for AI: [0, 2, 3, 4, 6]
# Best move selected: 3, Score: -20
# Available moves for AI: [0, 2, 3, 4, 6]
# Best move selected: 4, Score: -22
# Available moves for AI: [0, 2, 3, 4, 6]
# Best move selected: 4, Score: -33
# Available moves for AI: [0, 2, 3, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 2, 3]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 2]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 2
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: -7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 5
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 6, Score: 10
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: -7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 10
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 10
# Available moves for AI: [0, 1, 2, 4, 5, 6]
# Best move selected: 4, Score: 10
# Available moves for AI: [0, 1, 2, 4, 5, 6]
# Best move selected: 1, Score: -7
# Available moves for AI: [0, 1, 2, 4, 5, 6]
# Best move selected: 2, Score: -9
# Available moves for AI: [0, 1, 2, 4, 5, 6]
# Best move selected: 2, Score: -15
# Available moves for AI: [0, 1, 5, 6]
# Best move selected: 1, Score: -9
# Available moves for AI: [0, 1, 5, 6]
# Best move selected: 5, Score: -31
# Available moves for AI: [0, 1, 5, 6]
# Best move selected: 6, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 4
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: -2
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 9
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: -9
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 5
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: -25
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: -28
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: -41
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: -23
# Available moves for AI: [1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: -36
# Available moves for AI: [1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: -30
# Available moves for AI: [2, 3, 4, 5, 6]
# Best move selected: 2, Score: -25
# Available moves for AI: [3, 5, 6]
# Best move selected: 5, Score: -24
# Available moves for AI: [3, 5, 6]
# Best move selected: 5, Score: -17
# Available moves for AI: [3, 5, 6]
# Best move selected: 5, Score: 10
# Available moves for AI: [3, 6]
# Best move selected: 6, Score: 10
# Available moves for AI: [3, 6]
# Best move selected: 3, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 2
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 16
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 5
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: -5
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: -3
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -3
# Available moves for AI: [0, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: -17
# Available moves for AI: [0, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: -16
# Available moves for AI: [0, 2, 3, 4, 5, 6]
# Best move selected: 6, Score: -24
# Available moves for AI: [0, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: -18
# Available moves for AI: [0, 3, 4, 5, 6]
# Best move selected: 4, Score: 6
# Available moves for AI: [0, 3, 5, 6]
# Best move selected: 3, Score: 10
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 4
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: -2
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -1
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 1
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: -1
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 5
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: -4
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 2
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -16
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -20
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: -30
# Available moves for AI: [0, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: -26
# Available moves for AI: [0, 2, 4, 5, 6]
# Best move selected: 2, Score: -21
# Available moves for AI: [0, 4, 5, 6]
# Best move selected: 4, Score: -29
# Available moves for AI: [4, 5, 6]
# Best move selected: 4, Score: -38
# Available moves for AI: [6]
# Best move selected: 6, Score: 0
# Available moves for AI: [6]
# Best move selected: 6, Score: 0
# Available moves for AI: [6]
# Best move selected: 6, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 6, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: -2
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 6, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 9
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 1
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: -4
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 6, Score: 1
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -5
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: -14
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 10
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 3
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: -7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: -14
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: -19
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -9
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: -7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 6, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: -5
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 6, Score: -7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: -7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: -7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -9
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -23
# Available moves for AI: [0, 1, 2, 3, 4, 6]
# Best move selected: 2, Score: -22
# Available moves for AI: [0, 1, 2, 3, 4, 6]
# Best move selected: 2, Score: -29
# Available moves for AI: [0, 1, 3, 4, 6]
# Best move selected: 4, Score: -13
# Available moves for AI: [0, 1, 3]
# Best move selected: 1, Score: -5
# Available moves for AI: [0, 1, 3]
# Best move selected: 0, Score: -9
# Available moves for AI: [0, 3]
# Best move selected: 3, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 6, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 1
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: -7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 3
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 2
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: -5
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: -19
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: -28
# Available moves for AI: [0, 1, 2, 3, 4, 6]
# Best move selected: 3, Score: -38
# Available moves for AI: [0, 1, 2, 3, 4, 6]
# Best move selected: 2, Score: -7
# Available moves for AI: [0, 1, 2, 4, 6]
# Best move selected: 4, Score: -32
# Available moves for AI: [1, 2, 6]
# Best move selected: 6, Score: -39
# Available moves for AI: [1, 2, 6]
# Best move selected: 6, Score: -7
# Available moves for AI: [1, 2]
# Best move selected: 1, Score: -5
# Available moves for AI: [1, 2]
# Best move selected: 1, Score: 10
# Available moves for AI: [1, 2]
# Best move selected: 1, Score: 10
# Available moves for AI: [2]
# Best move selected: 2, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: -5
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 3
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 2
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: -5
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: -7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 6, Score: -13
# Available moves for AI: [0, 1, 3, 4, 5, 6]
# Best move selected: 0, Score: -14
# Available moves for AI: [0, 1, 3, 4, 5, 6]
# Best move selected: 3, Score: -21
# Available moves for AI: [0, 1, 3, 4, 5, 6]
# Best move selected: 1, Score: -23
# Available moves for AI: [0, 1, 3, 4, 5, 6]
# Best move selected: 1, Score: -23
# Available moves for AI: [0, 3, 4, 5, 6]
# Best move selected: 3, Score: -7
# Available moves for AI: [0, 4, 5, 6]
# Best move selected: 5, Score: -29
# Available moves for AI: [0, 4, 5, 6]
# Best move selected: 5, Score: -30
# Available moves for AI: [0, 4, 5, 6]
# Best move selected: 0, Score: -21
# Available moves for AI: [4, 6]
# Best move selected: 6, Score: -5
# Available moves for AI: [4, 6]
# Best move selected: 4, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 6, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 1
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: -3
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: -13
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: -9
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 6, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -18
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: -3
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: -7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: -14
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: -11
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: -11
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: -7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: -9
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: -14
# Available moves for AI: [0, 1, 2, 3, 5, 6]
# Best move selected: 6, Score: -33
# Available moves for AI: [0, 1, 2, 3, 5, 6]
# Best move selected: 2, Score: -17
# Available moves for AI: [0, 1, 2, 3, 5, 6]
# Best move selected: 2, Score: -28
# ...
# Best move selected: 2, Score: -9
# Available moves for AI: [0, 1, 2, 3, 4, 6]
# Best move selected: 3, Score: -9
# Available moves for AI: [0, 1, 2, 3, 4, 6]
# Best move selected: 2, Score: -24
# Available moves for AI: [0, 1, 2, 3, 4, 6]
# Best move selected: 4, Score: -24
# Available moves for AI: [0, 1, 3, 6]
# Best move selected: 0, Score: -7
# Available moves for AI: [1, 3, 6]
# Best move selected: 3, Score: -7
# Available moves for AI: [1]
# Best move selected: 1, Score: -9
# Available moves for AI: [1]
# Best move selected: 1, Score: 10
# Available moves for AI: [1]
# Best move selected: 1, Score: -9
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 4
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 5
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 6, Score: -2
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -5
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 5
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 6, Score: -4
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 3
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -5
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: -9
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: -21
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: -24
# Available moves for AI: [0, 1, 2, 3, 4, 6]
# Best move selected: 4, Score: -21
# Available moves for AI: [0, 1, 2, 3, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [1, 2, 3, 6]
# Best move selected: 1, Score: 0
# Available moves for AI: [3, 6]
# Best move selected: 3, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 4
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 6, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 10
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 5
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -5
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: -5
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: -6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: -2
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: -15
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: -24
# Available moves for AI: [0, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: -26
# Available moves for AI: [2, 3, 4, 5, 6]
# Best move selected: 2, Score: -31
# Available moves for AI: [3, 5, 6]
# Best move selected: 3, Score: 0
# Available moves for AI: [5, 6]
# Best move selected: 5, Score: 0
# Available moves for AI: [6]
# Best move selected: 6, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 4
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: -7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: -19
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: -21
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: -8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: -9
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: -2
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 6, Score: 4
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 6, Score: 5
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: -3
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 12
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 10
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 10
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: -5
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: -9
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 10
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 6, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 9
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: -5
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: -13
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 3
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 6, Score: -11
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: -16
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -24
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -15
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -11
# Available moves for AI: [0, 1, 2, 3, 4, 5]
# Best move selected: 0, Score: -25
# Available moves for AI: [0, 1, 2, 3, 4, 5]
# Best move selected: 3, Score: -8
# Available moves for AI: [0, 1, 2, 3, 4, 5]
# Best move selected: 1, Score: -19
# Available moves for AI: [0, 1, 2, 3, 4, 5]
# Best move selected: 3, Score: 8
# Available moves for AI: [0, 1, 2, 4, 5]
# Best move selected: 4, Score: -32
# Available moves for AI: [0, 2, 5]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 2, 5]
# Best move selected: 0, Score: 0
# Available moves for AI: [2, 5]
# Best move selected: 2, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 6, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 6, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: -1
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 2
# Available moves for AI: [0, 1, 2, 3, 5, 6]
# Best move selected: 5, Score: -2
# Available moves for AI: [0, 1, 2, 3, 5, 6]
# Best move selected: 3, Score: -2
# Available moves for AI: [0, 1, 2, 3, 5, 6]
# Best move selected: 3, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 3
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: -5
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: -7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: -9
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 10
# Available moves for AI: [0, 1, 2, 4, 5, 6]
# Best move selected: 4, Score: -29
# Available moves for AI: [0, 1, 4, 5, 6]
# Best move selected: 0, Score: -25
# Available moves for AI: [0, 1, 4, 5, 6]
# Best move selected: 1, Score: -21
# Available moves for AI: [4, 5, 6]
# Best move selected: 4, Score: -19
# Available moves for AI: [4, 5, 6]
# Best move selected: 4, Score: -16
# Available moves for AI: [5, 6]
# Best move selected: 6, Score: -16
# Available moves for AI: [5, 6]
# Best move selected: 5, Score: 10
# Available moves for AI: [5, 6]
# Best move selected: 5, Score: 0
# Available moves for AI: [6]
# Best move selected: 6, Score: 0
# Available moves for AI: [6]
# Best move selected: 6, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 1
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 5
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 6, Score: -3
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 2
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -8
# Available moves for AI: [0, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: -7
# Available moves for AI: [0, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -22
# Available moves for AI: [0, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -23
# Available moves for AI: [0, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: -22
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 4
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: -3
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: 2
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: -19
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: -28
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: -7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 10
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: -9
# Available moves for AI: [1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 10
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 4
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -2
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: -3
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 6
# Available moves for AI: [0, 1, 2, 4, 5, 6]
# Best move selected: 5, Score: -3
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 6, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 5
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 3
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 5
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 2
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 6, Score: -6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: -11
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: -21
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: -21
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 2, Score: -10
# Available moves for AI: [0, 1, 2, 3, 5, 6]
# Best move selected: 0, Score: -20
# Available moves for AI: [0, 1, 2, 3, 5]
# Best move selected: 2, Score: -22
# Available moves for AI: [0, 1, 2, 3, 5]
# Best move selected: 1, Score: -32
# Available moves for AI: [0, 1, 3, 5]
# Best move selected: 0, Score: -7
# Available moves for AI: [0, 3, 5]
# Best move selected: 0, Score: -7
# Available moves for AI: [3, 5]
# Best move selected: 3, Score: -9
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 6
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: 0
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 5
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: 2
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 3, Score: 3
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 4, Score: -5
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 5, Score: -16
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: -21
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: -8
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: -7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: -7
# Available moves for AI: [0, 1, 2, 3, 4, 5, 6]
# Best move selected: 0, Score: -7
# Available moves for AI: [1, 2, 3, 4, 5, 6]
# Best move selected: 1, Score: -7
# Available moves for AI: [1, 2, 4, 5, 6]
# Best move selected: 4, Score: -5
# Available moves for AI: [1, 2, 5, 6]
# Best move selected: 2, Score: 10
# ----Smart (Rule-based) agent vs mini-max agent----
#
# Results after 100 games:
# MiniMax Agent wins: 55
# Rule-Based Agent wins: 28
# Draws: 17
# Total time taken: 7853.99 seconds
